# %%
# Students part of the website

# %%
from bs4 import BeautifulSoup
import requests
import json

# %%
page = requests.get('https://www.greatschools.org/texas/austin/lake-travis-independent-school-district/#students')

# %%
page.status_code
# Out:
# 200

# %%
page.content
# Out:
# b'\n<!DOCTYPE html>\n<html xmlns:fb="http://ogp.me/ns/fb#">\n<head>\n  <title>Lake Travis Independent School District School District in Austin, TX. | GreatSchools</title>\n<meta name="description" content="Information to help parents choose the right public school for their children in the Lake Travis Independent School District." />\n<link rel="alternate" href="https://www.greatschools.org/texas/austin/lake-travis-independent-school-district/" hreflang="en" />\n<link rel="alternate" href="https://www.greatschools.org/texas/austin/lake-travis-independent-school-district/?lang=es" hreflang="es" />\n<link rel="canonical" href="https://www.greatschools.org/texas/austin/lake-travis-independent-school-district/" />\n\n  <!-- DNS prefetches -->\n  <link rel="dns-prefetch" href="//www.googletagmanager.com">\n<link rel="dns-prefetch" href="//pixel.quantserve.com">\n<link rel="dns-prefetch" href="//www.google-analytics.com">\n\n      <link rel="stylesheet" media="screen" href="/assets/commun
# ...

# %%
soup = BeautifulSoup(page.content, 'html.parser')

# %%
print(soup.prettify())
# Out:
# <!DOCTYPE html>
# <html xmlns:fb="http://ogp.me/ns/fb#">
#  <head>
#   <title>
#    Lake Travis Independent School District School District in Austin, TX. | GreatSchools
#   </title>
#   <meta content="Information to help parents choose the right public school for their children in the Lake Travis Independent School District." name="description"/>
#   <link href="https://www.greatschools.org/texas/austin/lake-travis-independent-school-district/" hreflang="en" rel="alternate"/>
#   <link href="https://www.greatschools.org/texas/austin/lake-travis-independent-school-district/?lang=es" hreflang="es" rel="alternate"/>
#   <link href="https://www.greatschools.org/texas/austin/lake-travis-independent-school-district/" rel="canonical"/>
#   <!-- DNS prefetches -->
#   <link href="//www.googletagmanager.com" rel="dns-prefetch"/>
#   <link href="//pixel.quantserve.com" rel="dns-prefetch"/>
#   <link href="//www.google-analytics.com" rel="dns-prefetch"/>
# ...

# %%
list(soup.children)
# Out:
# ['\n',
#  'html',
#  '\n',
#  <html xmlns:fb="http://ogp.me/ns/fb#">
#  <head>
#  <title>Lake Travis Independent School District School District in Austin, TX. | GreatSchools</title>
#  <meta content="Information to help parents choose the right public school for their children in the Lake Travis Independent School District." name="description"/>
#  <link href="https://www.greatschools.org/texas/austin/lake-travis-independent-school-district/" hreflang="en" rel="alternate"/>
#  <link href="https://www.greatschools.org/texas/austin/lake-travis-independent-school-district/?lang=es" hreflang="es" rel="alternate"/>
#  <link href="https://www.greatschools.org/texas/austin/lake-travis-independent-school-district/" rel="canonical"/>
#  <!-- DNS prefetches -->
#  <link href="//www.googletagmanager.com" rel="dns-prefetch"/>
#  <link href="//pixel.quantserve.com" rel="dns-prefetch"/>
#  <link href="//www.google-analytics.com" rel="dns-prefetch"/>
# ...

# %%
[type(item) for item in list(soup.children)]
# Out:
# [bs4.element.NavigableString,
#  bs4.element.Doctype,
#  bs4.element.NavigableString,
#  bs4.element.Tag,
#  bs4.element.NavigableString]

# %%
html = list(soup.children)[3]

# %%
list(html.children)
# Out:
# ['\n',
#  <head>
#  <title>Lake Travis Independent School District School District in Austin, TX. | GreatSchools</title>
#  <meta content="Information to help parents choose the right public school for their children in the Lake Travis Independent School District." name="description"/>
#  <link href="https://www.greatschools.org/texas/austin/lake-travis-independent-school-district/" hreflang="en" rel="alternate"/>
#  <link href="https://www.greatschools.org/texas/austin/lake-travis-independent-school-district/?lang=es" hreflang="es" rel="alternate"/>
#  <link href="https://www.greatschools.org/texas/austin/lake-travis-independent-school-district/" rel="canonical"/>
#  <!-- DNS prefetches -->
#  <link href="//www.googletagmanager.com" rel="dns-prefetch"/>
#  <link href="//pixel.quantserve.com" rel="dns-prefetch"/>
#  <link href="//www.google-analytics.com" rel="dns-prefetch"/>
# ...

# %%
body = list(html.children)[3]

# %%
list(body.children)
# Out:
# ['\n',
#  <div class="js-modal-container"></div>,
#  '\n',
#  ' Google Tag Manager ',
#  '\n',
#  <noscript><iframe height="0" src="https://www.googletagmanager.com/ns.html?id=GTM-KBSN4P" style="display:none;visibility:hidden" width="0"></iframe></noscript>,
#  '\n',
#  <script>(function(w,d,s,l,i){w[l]=w[l]||[];w[l].push({'gtm.start':
#    new Date().getTime(),event:'gtm.js'});var f=d.getElementsByTagName(s)[0],
#    j=d.createElement(s),dl=l!='dataLayer'?'&l='+l:'';j.async=true;j.src=
#    'https://www.googletagmanager.com/gtm.js?id='+i+dl;f.parentNode.insertBefore(j,f);
#    })(window,document,'script','dataLayer','GTM-KBSN4P');</script>,
#  '\n',
#  ' End Google Tag Manager ',
#  '\n',
#  <div class="print-logo"><div class="logo">
#  <a href="/">
#  <div></div>
#  </a>
#  </div></div>,
#  '\n',
#  <div class="header_display">
#  <div class="header_un">
#  <div class="un clearfix">
#  <div class="tr">
#  <div class="menu_layout_mobile">
# ...

# %%
tags= soup.find_all('script')
tags
# Out:
# [<script type="text/javascript">
#  //<![CDATA[
# ...

# %%
tags[11]
# Out:
# <script class="js-react-on-rails-component" data-component-name="TopSchoolsStatefulWrapper" data-dom-id="TopSchoolsStatefulWrapper-react-component-552ecc48-ba1d-4693-a006-cdacfb70d0d8" type="application/json">{"community":"district","schoolsData":{"elementary":[{"id":9933,"districtId":583,"districtName":"Lake Travis Independent School District","districtCity":"Austin","levelCode":"p,e","lat":30.309378,"lon":-97.920563,"name":"Lake Pointe Elementary School","gradeLevels":"PK-5","assigned":null,"address":{"street1":"11801 Sonoma Dr","street2":"","zip":"78738","city":"Austin"},"csaAwardYears":[],"rating":10,"ratingScale":"Top rated","schoolType":"public","state":"TX","type":"school","links":{"profile":"/texas/austin/9933-Lake-Pointe-Elementary-School/","reviews":"/texas/austin/9933-Lake-Pointe-Elementary-School/#Reviews","collegeSuccess":"/texas/austin/9933-Lake-Pointe-Elementary-School/#College_success"},"highlighted":false,"pinned":null,"testScoreRatingForEthnicity":null,"percentLowIn
# ...

# %%
# Teachers and staff

# %%
page2 = requests.get('https://www.greatschools.org/texas/austin/lake-travis-independent-school-district/#teachers-staff')

# %%
page2.status_code
# Out:
# 200

# %%
soup = BeautifulSoup(page.content, 'html.parser')

# %%
print(soup.prettify())
# Out:
# <!DOCTYPE html>
# <html xmlns:fb="http://ogp.me/ns/fb#">
#  <head>
#   <title>
#    Lake Travis Independent School District School District in Austin, TX. | GreatSchools
#   </title>
#   <meta content="Information to help parents choose the right public school for their children in the Lake Travis Independent School District." name="description"/>
#   <link href="https://www.greatschools.org/texas/austin/lake-travis-independent-school-district/" hreflang="en" rel="alternate"/>
#   <link href="https://www.greatschools.org/texas/austin/lake-travis-independent-school-district/?lang=es" hreflang="es" rel="alternate"/>
#   <link href="https://www.greatschools.org/texas/austin/lake-travis-independent-school-district/" rel="canonical"/>
#   <!-- DNS prefetches -->
#   <link href="//www.googletagmanager.com" rel="dns-prefetch"/>
#   <link href="//pixel.quantserve.com" rel="dns-prefetch"/>
#   <link href="//www.google-analytics.com" rel="dns-prefetch"/>
# ...

# %%
list(soup.children)
# Out:
# ['\n',
#  'html',
#  '\n',
#  <html xmlns:fb="http://ogp.me/ns/fb#">
#  <head>
#  <title>Lake Travis Independent School District School District in Austin, TX. | GreatSchools</title>
#  <meta content="Information to help parents choose the right public school for their children in the Lake Travis Independent School District." name="description"/>
#  <link href="https://www.greatschools.org/texas/austin/lake-travis-independent-school-district/" hreflang="en" rel="alternate"/>
#  <link href="https://www.greatschools.org/texas/austin/lake-travis-independent-school-district/?lang=es" hreflang="es" rel="alternate"/>
#  <link href="https://www.greatschools.org/texas/austin/lake-travis-independent-school-district/" rel="canonical"/>
#  <!-- DNS prefetches -->
#  <link href="//www.googletagmanager.com" rel="dns-prefetch"/>
#  <link href="//pixel.quantserve.com" rel="dns-prefetch"/>
#  <link href="//www.google-analytics.com" rel="dns-prefetch"/>
# ...

# %%
[type(item) for item in list(soup.children)]
# Out:
# [bs4.element.NavigableString,
#  bs4.element.Doctype,
#  bs4.element.NavigableString,
#  bs4.element.Tag,
#  bs4.element.NavigableString]

# %%
html = list(soup.children)[3]

# %%
list(html.children)
# Out:
# ['\n',
#  <head>
#  <title>Lake Travis Independent School District School District in Austin, TX. | GreatSchools</title>
#  <meta content="Information to help parents choose the right public school for their children in the Lake Travis Independent School District." name="description"/>
#  <link href="https://www.greatschools.org/texas/austin/lake-travis-independent-school-district/" hreflang="en" rel="alternate"/>
#  <link href="https://www.greatschools.org/texas/austin/lake-travis-independent-school-district/?lang=es" hreflang="es" rel="alternate"/>
#  <link href="https://www.greatschools.org/texas/austin/lake-travis-independent-school-district/" rel="canonical"/>
#  <!-- DNS prefetches -->
#  <link href="//www.googletagmanager.com" rel="dns-prefetch"/>
#  <link href="//pixel.quantserve.com" rel="dns-prefetch"/>
#  <link href="//www.google-analytics.com" rel="dns-prefetch"/>
# ...

# %%
tags= soup.find_all('script')
tags
# Out:
# [<script type="text/javascript">
#  //<![CDATA[
# ...

# %%
tags[14]
# Out:
# <script class="js-react-on-rails-component" data-component-name="AcademicsDataModuleWrapper" data-dom-id="AcademicsDataModuleWrapper-react-component-e4521c16-0baf-4c66-8b79-2e94d839be72" type="application/json">{"title":"Academics","anchor":"Academics","subtitle":"Is this district offering opportunity for all its students, or leaving some kids behind? Successful districts are working to \u003ca href=/gk/articles/the-achievement-gap-is-your-school-helping-all-students-succeed\u003e close the achievement gap.\u003c/a\u003e\n","info_text":null,"icon_classes":"icon-pie","sources":"\u003cdiv class=\"sourcing\"\u003e\u003ch1\u003eGreatSchools district data sources \u0026amp; information\u003c/h1\u003e\u003cdiv\u003e\u003ch4\u003eState of Texas Assessments of Academic Readiness (STAAR)\u003c/h4\u003e\u003cp\u003eReading, Writing, English, English 2, Math, Algebra I, Science, Social Studies, Biology I, US History\u003c/p\u003e\u003cp\u003eIn 2017-2018, the State of Texas Assessments of Acade
# ...

# %%
tags[16]
# Out:
# <script class="js-react-on-rails-component" data-component-name="StemCourses" data-dom-id="StemCourses-react-component-6231bead-02ae-44a1-a980-32c764abc011" type="application/json">{"courses":[{"breakdown":"8th grade Algebra 1 participation rate","score":43,"label":"43","state_average":25,"visualization":"PersonBar","tooltip_html":"Most districts consider \u003ca href=\"/gk/articles/why-algebra/\"\u003eAlgebra 1\u003c/a\u003e an advanced course in grades 7 or 8 and a standard course in high school. This reflects the percentage of 8th grade students in this district who took Algebra 1 compared to the state average. Here's what you need to know about \u003ca href=\"/gk/articles/algebra-middle-school-math-track/\"\u003emath tracking\u003c/a\u003e."},{"breakdown":"8th grade Algebra 1 pass rate","score":94,"label":"94","state_average":86,"visualization":"SingleBar","tooltip_html":"This reflects the percentage of 8th grade students in this district who passed \u003ca href=\"/gk/articles/wh
# ...

# %%
tags[17]
# Out:
# <script class="js-react-on-rails-component" data-component-name="Students" data-dom-id="Students-react-component-b6ddbed3-6af1-45ea-9b28-ac209df4f492" type="application/json">{"ethnicityData":[{"breakdown":"Asian","district_value":5.8309},{"breakdown":"Native Hawaiian or Other Pacific Islander","district_value":0.0768},{"breakdown":"Black","district_value":1.3929},{"breakdown":"White","district_value":67.6561},{"breakdown":"Two or more races","district_value":4.4861},{"breakdown":"Hispanic","district_value":20.2882},{"breakdown":"Native American","district_value":0.269}],"subgroupsData":{"English learners":[{"breakdown":"All students","district_value":5.5908,"source":"National Center for Education Statistics","year":2018,"state_average":17.1499}],"Students participating in free or reduced-price lunch program":[{"breakdown":"All students","district_value":11.5946,"source":"National Center for Education Statistics","year":2018,"state_average":58.6722}]},"genderData":{"Male":[{"breakdow
# ...

# %%
tags[18]
# Out:
# <script class="js-react-on-rails-component" data-component-name="TeachersStaffWrapper" data-dom-id="TeachersStaffWrapper-react-component-750987d9-4b57-4e81-9599-c8558bf98ed9" type="application/json">{"data":{"state":"TX","district_id":583,"main_staff":[{"name":"Students per teacher","tooltip":"The average number of students per full-time teacher in this district; please note that this is not a reflection of average class size.","type":"ratio","district_value":17,"state_value":15,"year":2016,"source":"Civil Rights Data Collection"},{"name":"Students per counselor","tooltip":"The average number of students per counselor in this district.","type":"ratio","district_value":619,"state_value":426,"year":2016,"source":"Civil Rights Data Collection"},{"name":"Percentage of teachers with 3 or more years experience","tooltip":"The percentage of full-time teachers in this district who have been teaching for 3 or more years.","type":"percent_bar","district_value":90,"state_value":85,"year":2016,"
# ...

# %%
tags[20]
# Out:
# <script class="js-react-on-rails-component" data-component-name="Finance" data-dom-id="Finance-react-component-1c0530ca-2262-4cb3-b0d0-27361b457858" type="application/json">{"dataValues":[{"data_type":"Total Revenue","name":"Total district revenue","district_value":"141.3 million","state_value":"49.9 million","value_label":"District","year":2016,"source":{"name":"Total district revenue","description":"This reflects the total annual funds this district received from local, state, and federal sources, compared to the average across the state.  (See examples below).","source_and_year":"National Center for Education Statistics, 2016"},"type":"large_dollar_amt","tooltip":"This reflects the total annual funds this district received from local, state, and federal sources, compared to the average across the state.  (See examples below)."},{"data_type":"Per Pupil Revenue","name":"Average revenue per student","district_value":"$15,304","state_value":"$11,363","value_label":"District","year":20
# ...

# %%
# Schools section- maybe it encompasses entire website

# %%
page3 = requests.get('https://www.greatschools.org/texas/austin/lake-travis-independent-school-district/#schools')

# %%
page3.status_code
# Out:
# 200

# %%
soup3 = BeautifulSoup(page3.content, 'html.parser')

# %%
print(soup3.prettify())
# Out:
# <!DOCTYPE html>
# <html xmlns:fb="http://ogp.me/ns/fb#">
#  <head>
#   <title>
#    Lake Travis Independent School District School District in Austin, TX. | GreatSchools
#   </title>
#   <meta content="Information to help parents choose the right public school for their children in the Lake Travis Independent School District." name="description"/>
#   <link href="https://www.greatschools.org/texas/austin/lake-travis-independent-school-district/" hreflang="en" rel="alternate"/>
#   <link href="https://www.greatschools.org/texas/austin/lake-travis-independent-school-district/?lang=es" hreflang="es" rel="alternate"/>
#   <link href="https://www.greatschools.org/texas/austin/lake-travis-independent-school-district/" rel="canonical"/>
#   <!-- DNS prefetches -->
#   <link href="//www.googletagmanager.com" rel="dns-prefetch"/>
#   <link href="//pixel.quantserve.com" rel="dns-prefetch"/>
#   <link href="//www.google-analytics.com" rel="dns-prefetch"/>
# ...

# %%
list(soup3.children)
# Out:
# ['\n',
#  'html',
#  '\n',
#  <html xmlns:fb="http://ogp.me/ns/fb#">
#  <head>
#  <title>Lake Travis Independent School District School District in Austin, TX. | GreatSchools</title>
#  <meta content="Information to help parents choose the right public school for their children in the Lake Travis Independent School District." name="description"/>
#  <link href="https://www.greatschools.org/texas/austin/lake-travis-independent-school-district/" hreflang="en" rel="alternate"/>
#  <link href="https://www.greatschools.org/texas/austin/lake-travis-independent-school-district/?lang=es" hreflang="es" rel="alternate"/>
#  <link href="https://www.greatschools.org/texas/austin/lake-travis-independent-school-district/" rel="canonical"/>
#  <!-- DNS prefetches -->
#  <link href="//www.googletagmanager.com" rel="dns-prefetch"/>
#  <link href="//pixel.quantserve.com" rel="dns-prefetch"/>
#  <link href="//www.google-analytics.com" rel="dns-prefetch"/>
# ...

# %%
[type(item) for item in list(soup3.children)]
# Out:
# [bs4.element.NavigableString,
#  bs4.element.Doctype,
#  bs4.element.NavigableString,
#  bs4.element.Tag,
#  bs4.element.NavigableString]

# %%
html3 = list(soup3.children)[3]

# %%
tags3= soup3.find_all('script')

# %%
tags3[20]
# Out:
# <script class="js-react-on-rails-component" data-component-name="Finance" data-dom-id="Finance-react-component-09201bdd-56c4-44cd-b39d-dc1896ac2af2" type="application/json">{"dataValues":[{"data_type":"Total Revenue","name":"Total district revenue","district_value":"141.3 million","state_value":"49.9 million","value_label":"District","year":2016,"source":{"name":"Total district revenue","description":"This reflects the total annual funds this district received from local, state, and federal sources, compared to the average across the state.  (See examples below).","source_and_year":"National Center for Education Statistics, 2016"},"type":"large_dollar_amt","tooltip":"This reflects the total annual funds this district received from local, state, and federal sources, compared to the average across the state.  (See examples below)."},{"data_type":"Per Pupil Revenue","name":"Average revenue per student","district_value":"$15,304","state_value":"$11,363","value_label":"District","year":20
# ...

# %%
def check_script_tag(url):
    page = requests.get(url)
    soup = BeautifulSoup(page.content, 'html.parser')
    tags= soup.find_all('script')
    print(soup.find_all('title'))
    print(tags[20])

# %%
check_script_tag('https://www.greatschools.org/texas/buna/buna-independent-school-district/#schools')
# Out:
# [<title>Buna Independent School District School District in Buna, TX. | GreatSchools</title>]
# ...
